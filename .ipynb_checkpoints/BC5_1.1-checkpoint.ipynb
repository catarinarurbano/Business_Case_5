# %% [markdown]
# # Business Case 5

# %% [markdown]
# ## Mind Over Data - Demand Forecasting

# %% [markdown]
# #### Made by:
# * Catarina Candeias (m20200656@novaims.unl.pt)
# * Catarina Urbano (m20200607@novaims.unl.pt)
# * Margarida Pereira (m20201038@novaims.unl.pt)
# * Rita Ferreira (m20200661@novaims.unl.pt)

# %% [markdown]
# ### Table of contents:

# %% [markdown]
# * [1. Business Understanding](#1)
# * [2. Data Understanding](#2)
# * [3. Data Preparation](#3)
# * [4. Modeling and Evaluation](#4)
#     * [4.1. Association Rules](#4.1)
#     * [4.2. Customers Segmentation by product](#4.2)
# * [5. Deployment](#5)

# %% [markdown]
# # 1. Business Understanding <a class="anchor" id="1"></a>
#
# This section can be seen in detail in our report

# %% [markdown]
# # 2. Data Understanding <a class="anchor" id="2"></a>

# %% [markdown]
# #### Imports

# %%
import pandas as pd
# import pandas_profiling
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import math
from datetime import datetime
import calendar

sns.set_style(style='white')

import warnings
warnings.filterwarnings("always", message='',category=FutureWarning)
import plotly.express as px

# %% [markdown]
# ### 2.1. Collect Initial Data <a class="anchor" id="2.1"></a>

# %%
# Load data
df = pd.read_csv('df_preprocessed.csv')
df.drop(columns=['Unnamed: 0'], inplace=True)
df.head()
# Out:
#    ProductFamily_ID  ProductCategory_ID  ProductBrand_ID  ProductName_ID  \
# 0                 1                  33              313             657
# 1                 1                  33              313             657
# 2                 1                  33              313             657
# 3                 1                  33              313             657
# 4                 1                  33              313             657
#
#    ProductPackSKU_ID  Point-of-Sale_ID        Date  Sell-out units  \
# 0               1984                 2  2018-06-21             1.0
# 1               1984                 2  2018-08-08             1.0
# 2               1984                 2  2018-08-23             1.0
# 3               1984                 2  2018-10-07             1.0
# 4               1984                 2  2018-12-15             1.0
#
#    Sell-out values
# 0            655.0
# 1            655.0
# 2            655.0
# 3            655.0
# 4            655.0

# %% [markdown]
# ### 2.2. Describe, explore and assess data quality <a class="anchor" id="2.2"></a>
# Note that this is an interactive process, so in order to perform better exploration and assessment of our data some data cleaning was needed in this step

# %%
# Get the row and column count,columns and their datatypes and presence of null values.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91161169 entries, 0 to 91161168
# Data columns (total 9 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ProductFamily_ID    int64
#  1   ProductCategory_ID  int64
#  2   ProductBrand_ID     int64
#  3   ProductName_ID      int64
#  4   ProductPackSKU_ID   int64
#  5   Point-of-Sale_ID    int64
#  6   Date                object
#  7   Sell-out units      float64
#  8   Sell-out values     float64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 6.1+ GB

# %% [markdown]
# ##### Note:
# - the variable Date should be datetime and not a float

# %%
# shape of df:
df.shape
# Out:
# (91161169, 9)

# %%
# Check for duplicates:
# df.drop_duplicates().shape

# %%
# To avoid errors:
df.replace("", np.nan, inplace=True)

# %%
# Checking if there are white spaces where they aren´t supposed to be
lst = []
for column in df.columns:
    if (df[column].isin([' ']).sum()>0):
        lst.append(column)
print(lst)

# %%
# Check for missing values:
display(df.isna().sum())
# Out:
# ProductFamily_ID      0
# ProductCategory_ID    0
# ProductBrand_ID       0
# ProductName_ID        0
# ProductPackSKU_ID     0
# Point-of-Sale_ID      0
# Date                  0
# Sell-out units        0
# Sell-out values       0
# dtype: int64

# %%
# some statistics:
df[['Sell-out units','Sell-out values']].describe(include='all')
# Out:
#        Sell-out units  Sell-out values
# count    9.116117e+07     9.116117e+07
# mean     2.180195e+00     3.518611e+03
# std      2.291201e+00     6.657410e+03
# min      0.000000e+00    -1.000000e+01
# 25%      1.000000e+00     8.600000e+02
# 50%      1.000000e+00     1.654000e+03
# 75%      2.000000e+00     3.420000e+03
# max      2.870000e+02     6.625750e+05

# %% [markdown]
# #### Outliers detection

# %%
metric_features =["Sell-out units","Sell-out values"]

# %%
# check boxplots and univariate outliers

# All Numeric Variables' Box Plots in one figure
sns.set()

# Prepare figure. Create individual axes where each box plot will be placed
fig, axes = plt.subplots(1, 2, figsize=(25, 9), squeeze=True)

# Plot data
# Iterate across axes objects and associate each box plot:
for ax, feat in zip(axes.flatten(), metric_features): 
    sns.boxplot(x=df[feat], ax=ax)
#     ax.set_title(feat, y=-0.21)

# Adjusting my subplots:
fig.tight_layout()

# Layout
# Add a centered title to the figure:
title = "Numeric Variables' Box Plots"
plt.suptitle(title,y=1)

plt.show()

# %% [markdown]
# ##### Some required data preparation to enable good data exploration at this step:

# %%
#Convert to proper format
df['Date'] = pd.to_datetime(df['Date'])

# 'Sell-out units' should be integer:
df['Sell-out units'] = df['Sell-out units'].astype(int)

# %%
#convert daily data to weekly

# %% [markdown]
# ### Visualizations

# %% [markdown]
# Dataframe with Quarterly information:

# %%
df_quarter = df.groupby(by=[df['Date'].dt.to_period('Q'),'ProductFamily_ID','ProductCategory_ID','ProductBrand_ID','ProductName_ID','ProductPackSKU_ID','Point-of-Sale_ID'])[['Sell-out units','Sell-out values']].sum()
df_quarter
# Out:
#                                                                                                               Sell-out units  \
# Date   ProductFamily_ID ProductCategory_ID ProductBrand_ID ProductName_ID ProductPackSKU_ID Point-of-Sale_ID
# 2016Q1 1                33                 313             657            1984              4                              1
#                                                                                             6                              1
#                                                                                             8                             10
#                                                                                             9                              1
#                                                                                             13                            35
# ...                                                                                                                      ...
# 2019Q4 21               169                1472            1228           3602              342                            1
#                         170                547             2440           7574              196                            1
#                                                                                             224                            1
#                                                                                             349                            1
#                                            719             2497           7716              249                            1
#
#                                                                                                               Sell-out values
# Date   ProductFamily_ID ProductCategory_ID ProductBrand_ID ProductName_ID ProductPackSKU_ID Point-of-Sale_ID
# 2016Q1 1                33                 313             657            1984              4                           595.0
#                                                                                             6                           430.0
#                                                                                             8                          5950.0
#                                                                                             9                           840.0
#                                                                                             13                        28695.0
# ...                                                                                                                       ...
# 2019Q4 21               169                1472            1228           3602              342                        1495.0
#                         170                547             2440           7574              196                        2250.0
#                                                                                             224                        2875.0
#                                                                                             349                        1591.0
#                                            719             2497           7716              249                        2495.0
#
# [8067685 rows x 2 columns]

# %% [markdown]
# ##### Most sold products

# %%
products_grouped = df.groupby(['ProductName_ID']).agg({'Sell-out units': 'sum'}).reset_index()
products_grouped['percentage']  = products_grouped['Sell-out units']/(products_grouped['Sell-out units'].sum())*100
products_grouped.rename(columns = {'ProductName_ID':'Product ID', 'Sell-out units':'Sell-out units sum'}, inplace = True)
products_grouped = products_grouped.sort_values(['Sell-out units sum'], ascending = 0)
products_grouped
# Out:
#       Product ID  Sell-out units sum    percentage
# 1265        1277             3170644  1.595299e+00
# 2579        2609             3070767  1.545047e+00
# 478          481             2983615  1.501196e+00
# 983          993             2837871  1.427866e+00
# 1136        1147             2801152  1.409391e+00
# ...          ...                 ...           ...
# 2493        2522                   1  5.031468e-07
# 1540        1555                   1  5.031468e-07
# 2490        2519                   1  5.031468e-07
# 1549        1564                   1  5.031468e-07
# 2376        2402                   1  5.031468e-07
#
# [2820 rows x 3 columns]

# %%
plt.figure(figsize=(15,9))
sns.barplot(data=products_grouped.head(30),x="Product ID",y="Sell-out units sum",orient="v",color='indianred')
plt.xticks(rotation=90)
plt.title("Best Selling Products - Monetaty Value")
plt.xlabel('Product ID')
plt.ylabel("Sell-out units sum")
# Out:
# Text(0, 0.5, 'Sell-out units sum')

# %% [markdown]
# #### Point of sale as a whole:

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))
# Point of sale with more items sold in each quarter
aux2 = aux.reset_index().groupby(by=['Date','Point-of-Sale_ID'])['Sell-out units'].sum().to_frame().reset_index()
aux2 = aux2.groupby(by=['Date']).max()
aux2.reset_index(inplace=True)
sns.barplot(x="Date", y="Sell-out units",hue='Point-of-Sale_ID', data=aux2,ax=ax1)
ax1.tick_params(axis='x',labelrotation=70)
ax1.set_title('Points of sale with more items sold in each quarter')
# plt.show()

# Point of sale with more Sell-out value in each quarter
aux2 = aux.reset_index().groupby(by=['Date','Point-of-Sale_ID'])['Sell-out values'].sum().to_frame().reset_index()
aux2 = aux2.groupby(by=['Date']).max()
aux2.reset_index(inplace=True)
ax2 = sns.barplot(x="Date", y="Sell-out values",hue='Point-of-Sale_ID', data=aux2,ax=ax2)
ax2.tick_params(axis='x',labelrotation=70)
ax2.set_title('Points of sale with more Sell-out value in each quarter')
plt.show()

# %% [markdown]
# #### Top products sold in each quarter for a certain point of sale

# %%
def top_products_quarter(df,Point_of_Sale_ID,quarter=None):
    aux=df.reset_index()[df.reset_index()['Point-of-Sale_ID']==Point_of_Sale_ID]
    if quarter!=None:
        aux_df = aux[aux['Date']==quarter].groupby(by=['Date','ProductName_ID'])[['Sell-out units']].sum().nlargest(3,'Sell-out units')
        title = 'Top products sold in the '+str(quarter)+' for the point of sale with ID: '+str(Point_of_Sale_ID)
    else:
        aux_df=pd.DataFrame()
        for i in df_quarter.reset_index().Date.unique():
            aux1 = aux[aux['Date']==i].groupby(by=['Date','ProductName_ID'])[['Sell-out units']].sum().nlargest(3,'Sell-out units')
            aux_df=pd.concat([aux_df, aux1])
            title = 'Top products sold in each quarter for the point of sale with ID '+str(Point_of_Sale_ID)
    aux_df.reset_index(inplace=True)
    aux_df.Date = aux_df.Date.astype(str) 
    
    fig = px.bar(aux_df, x="Date", y="Sell-out units", color='ProductName_ID', title=title)
    return fig

# %%
top_products_quarter(df_quarter,40)
# Out:
# <div>                            <div id="68e6994f-1375-4bf7-9510-ef1a2a98b664" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("68e6994f-1375-4bf7-9510-ef1a2a98b664")) {                    Plotly.newPlot(                        "68e6994f-1375-4bf7-9510-ef1a2a98b664",                        [{"alignmentgroup": "True", "hovertemplate": "Date=%{x}<br>Sell-out units=%{y}<br>ProductName_ID=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [481, 2379, 1071, 2379, 1277, 1071, 2379, 1277, 1071, 2379, 481, 1277, 2379, 1277, 130, 2379, 1277, 2609, 1277, 2379, 2609, 1277, 2379, 130, 1277, 993, 130, 1277, 2379, 2609, 1277, 2379, 207, 1277, 2379, 2609, 481, 1277, 2609, 1277, 2609, 2379, 1277, 207, 2609, 1277, 2379, 2609], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["2016Q1", "2016Q1", "2016Q1", "2016Q2", "2016Q2", "2016Q2", "2016Q3", "2016Q3", "2016Q3", "2016Q4", "2016Q4", "2016Q4", "2017Q1", "2017Q1", "2017Q1", "2017Q2", "2017Q2", "2017Q2", "2017Q3", "2017Q3", "2017Q3", "2017Q4", "2017Q4", "2017Q4", "2018Q1", "2018Q1", "2018Q1", "2018Q2", "2018Q2", "2018Q2", "2018Q3", "2018Q3", "2018Q3", "2018Q4", "2018Q4", "2018Q4", "2019Q1", "2019Q1", "2019Q1", "2019Q2", "2019Q2", "2019Q2", "2019Q3", "2019Q3", "2019Q3", "2019Q4", "2019Q4", "2019Q4"], "xaxis": "x", "y": [614, 593, 561, 590, 549, 478, 658, 550, 422, 626, 619, 550, 643, 626, 593, 622, 599, 424, 666, 657, 455, 671, 552, 507, 645, 609, 590, 672, 546, 509, 665, 580, 508, 762, 612, 485, 624, 620, 551, 671, 534, 527, 724, 543, 541, 270, 214, 208], "yaxis": "y"}],                        {"barmode": "relative", "coloraxis": {"colorbar": {"title": {"text": "ProductName_ID"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "# ...

# %% [markdown]
# # ----------------------------------

# %% [markdown]
# #### Market Share

# %%
# variables = ['ProductFamily_ID','ProductCategory_ID','ProductBrand_ID']

# Reducing the cardinality  

# We are merging the categories that have a frequency of observations lower than 2.5% in the category 'OTHER'
# for feature in variables:
   # serie=df[feature].value_counts()/len(df)
   # top = df[feature].value_counts()[:len(serie[serie>=0.025])].index
   # df = df.loc[~df[feature].isin(top), feature] = 'OTHER'

# %% [markdown]
# ##### Product Family

# %%
Product_Family =  df.groupby('ProductFamily_ID')['Sell-out values'].mean()

# %%
labels = Product_Family.index
values = Product_Family.values

fig1, ax1 = plt.subplots()
ax1.pie(values, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)

ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.


ax1.set_title("Percentage of the Product Family ID by Market Market Share")

plt.show()

# %% [markdown]
# ##### Product Category

# %%
Product_Category = df.groupby('ProductCategory_ID')['Sell-out values'].mean()

# %%
labels = Product_Category.index
values = Product_Category.values

fig1, ax1 = plt.subplots()
ax1.pie(values, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)

ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.


ax1.set_title("Percentage of the Product Family ID by Market Market Share")

plt.show()

# %% [markdown]
# ##### Product Brand

# %%
Product_Brand = df.groupby('ProductBrand_ID')['Sell-out values'].mean()

# %%
labels = Product_Brand.index
values = Product_Brand.values

fig1, ax1 = plt.subplots()
ax1.pie(values, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)

ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.


ax1.set_title("Percentage of the Product Family ID by Market Market Share")

plt.show()

# %% [markdown]
# ##### Preferences

# %% [markdown]
# ##### Product Category

# %%
Product_Family_pref =  df.groupby('ProductFamily_ID')['Sell-out units'].mean()

# %%
labels = Product_Family_pref.index
values = Product_Family_pref.values

fig1, ax1 = plt.subplots()
ax1.pie(values, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)

ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.


ax1.set_title("Percentage of the Product Family ID by Market Market Share")

plt.show()

# %% [markdown]
# ##### Product Category

# %%
Product_Category_pref = df.groupby('ProductCategory_ID')['Sell-out units'].mean()

# %%
labels = Product_Category_pref.index
values = Product_Category_pref.values

fig1, ax1 = plt.subplots()
ax1.pie(values, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)

ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.


ax1.set_title("Percentage of the Product Family ID by Market Market Share")

plt.show()

# %% [markdown]
# ##### Product Brand

# %%
Product_Brand_pref = df.groupby('ProductBrand_ID')['Sell-out units'].mean()

# %%
labels = Product_Brand_pref.index
values = Product_Brand_pref.values

fig1, ax1 = plt.subplots()
ax1.pie(values, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)

ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.


ax1.set_title("Percentage of the Product Family ID by Market Market Share")

plt.show()

# %% [markdown]
# #### At What Day Of The Week People Order?

# %%
day = []
def get_dow(x):
    return calendar.day_name[x.weekday()]
day = df['Date'].map(get_dow)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-21-ee636640bccf> in <module>
#       2 def get_dow(x):
#       3     return calendar.day_name[x.weekday()]
# ----> 4 day = df['Date'].map(get_dow)
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    3980         dtype: object
#    3981         """
# -> 3982         new_values = super()._map_values(arg, na_action=na_action)
#    3983         return self._constructor(new_values, index=self.index).__finalize__(
#    3984             self, method="map"
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#    1142             map_f = lambda values, f: values.map(f)
#    1143         else:
# -> 1144             values = self.astype(object)._values
#    1145             if na_action == "ignore":
#    1146
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# --> 595         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     596
#     597     def convert(
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, **kwargs)
#     404                 applied = b.apply(f, **kwargs)
#     405             else:
# --> 406                 applied = getattr(b, f)(**kwargs)
#     407             result_blocks = _extend_blocks(applied, result_blocks)
#     408
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#    2098
#    2099         # delegate
# -> 2100         return super().astype(dtype=dtype, copy=copy, errors=errors)
#    2101
#    2102     def _can_hold_element(self, element: Any) -> bool:
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     588
#     589             else:
# --> 590                 values = self.get_values(dtype=dtype)
#     591
#     592             # _astype_nansafe works fine with 1-d only
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\internals\blocks.py in get_values(self, dtype)
#    2020         if is_object_dtype(dtype):
#    2021             # DTA/TDA constructor and astype can handle 2D
# -> 2022             return self._holder(self.values).astype(object)
#    2023         return self.values
#    2024
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\arrays\datetimes.py in astype(self, dtype, copy)
#     597         elif is_period_dtype(dtype):
#     598             return self.to_period(freq=dtype.freq)
# --> 599         return dtl.DatetimeLikeArrayMixin.astype(self, dtype, copy)
#     600
#     601     # -----------------------------------------------------------------
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\arrays\datetimelike.py in astype(self, dtype, copy)
#     628
#     629         if is_object_dtype(dtype):
# --> 630             return self._box_values(self.asi8.ravel()).reshape(self.shape)
#     631         elif is_string_dtype(dtype) and not is_categorical_dtype(dtype):
#     632             if is_extension_array_dtype(dtype):
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\arrays\datetimelike.py in _box_values(self, values)
#     484         apply box func to passed values
#     485         """
# --> 486         return lib.map_infer(values, self._box_func)
#     487
#     488     def __iter__(self):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\arrays\datetimes.py in <lambda>(x)
#     474     @property
#     475     def _box_func(self):
# --> 476         return lambda x: Timestamp(x, freq=self.freq, tz=self.tz)
#     477
#     478     @property
#
# pandas\_libs\tslibs\timestamps.pyx in pandas._libs.tslibs.timestamps.Timestamp.__new__()
#
# pandas\_libs\tslibs\timestamps.pyx in pandas._libs.tslibs.timestamps.create_timestamp_from_ts()
#
# MemoryError:

# %%
plt.figure(figsize = (10,6))
ax2 = sns.barplot(x = "index", y = "Date", data = day.value_counts().reset_index(), color = "indianred")
ax2.set(xlabel='Day', ylabel='Count')
ax2.set_title('What day of the week are most items bought?')
plt.show()

# %%
# visualizing the unitprice

plt.rcParams['figure.figsize'] = (15, 7)
plt.style.use('fivethirtyeight')
sns.distplot(df['Sell-out values'], color = 'indianred')
plt.title('Distribution of Unit price', fontsize = 20)
plt.xlabel('Different Unit Price for different items')
plt.ylabel('count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-22-027adf4c3fe1> in <module>
#       3 plt.rcParams['figure.figsize'] = (15, 7)
#       4 plt.style.use('fivethirtyeight')
# ----> 5 sns.distplot(df['Sell-out values'], color = 'indianred')
#       6 plt.title('Distribution of Unit price', fontsize = 20)
#       7 plt.xlabel('Different Unit Price for different items')
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2617     if kde:
#    2618         kde_color = kde_kws.pop("color", color)
# -> 2619         kdeplot(a, vertical=vertical, ax=ax, color=kde_color, **kde_kws)
#    2620         if kde_color != color:
#    2621             kde_kws["color"] = kde_color
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in kdeplot(x, y, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, weights, hue, palette, hue_order, hue_norm, multiple, common_norm, common_grid, levels, thresh, bw_method, bw_adjust, log_scale, color, fill, data, data2, **kwargs)
#    1728             plot_kws["color"] = color
#    1729
# -> 1730         p.plot_univariate_density(
#    1731             multiple=multiple,
#    1732             common_norm=common_norm,
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in plot_univariate_density(self, multiple, common_norm, common_grid, fill, legend, estimate_kws, **plot_kws)
#     908
#     909         # Do the computation
# --> 910         densities = self._compute_univariate_density(
#     911             self.data_variable,
#     912             common_norm,
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in _compute_univariate_density(self, data_variable, common_norm, common_grid, estimate_kws, log_scale)
#     283         estimator = KDE(**estimate_kws)
#     284
# --> 285         all_data = self.plot_data.dropna()
#     286
#     287         if set(self.variables) - {"x", "y"}:
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    5005             agg_obj = self.take(indices, axis=agg_axis)
#    5006
# -> 5007         count = agg_obj.count(axis=agg_axis)
#    5008
#    5009         if thresh is not None:
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py in count(self, axis, level, numeric_only)
#    8476             else:
#    8477                 # GH13407
# -> 8478                 series_counts = notna(frame).sum(axis=axis)
#    8479                 counts = series_counts.values
#    8480                 result = self._constructor_sliced(
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   11420                 name, axis=axis, level=level, skipna=skipna, min_count=min_count
#   11421             )
# > 11422         return self._reduce(
#   11423             func,
#   11424             name=name,
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    8652
#    8653             try:
# -> 8654                 result = func(values)
#    8655
#    8656             except TypeError:
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py in func(values)
#    8573                 return extract_array(values)._reduce(name, skipna=skipna, **kwds)
#    8574             else:
# -> 8575                 return op(values, axis=axis, skipna=skipna, **kwds)
#    8576
#    8577         def _get_data(axis_matters):
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      69             try:
#      70                 with np.errstate(invalid="ignore"):
# ---> 71                     return f(*args, **kwargs)
#      72             except ValueError as e:
#      73                 # we want to transform an object array
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\nanops.py in nansum(values, axis, skipna, min_count, mask)
#     507     elif is_timedelta64_dtype(dtype):
#     508         dtype_sum = np.float64
# --> 509     the_sum = values.sum(axis, dtype=dtype_sum)
#     510     the_sum = _maybe_null_out(the_sum, axis, mask, values.shape, min_count=min_count)
#     511
#
# ~\anaconda3\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      45 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      46          initial=_NoValue, where=True):
# ---> 47     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      48
#      49 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# MemoryError: Unable to allocate 696. MiB for an array with shape (91161169, 1) and data type int64
