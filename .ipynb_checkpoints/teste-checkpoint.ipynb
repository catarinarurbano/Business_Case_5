# %%
import pandas as pd

# %%
aux0=pd.read_csv('df_0 - Cópia.csv')
aux0.drop(columns=['Unnamed: 0'],inplace=True)
aux1=pd.read_csv('df_1 - Cópia.csv')
aux1.drop(columns=['Unnamed: 0'],inplace=True)

# %%
aux=pd.concat([aux0,aux1])

# %%
aux
# Out:
#          ProductFamily_ID  ProductCategory_ID  ProductBrand_ID  \
# 0                       1                  33              313
# 1                       1                  33              313
# 2                       1                  33              313
# 3                       1                  33              313
# 4                       1                  33              313
# ...                   ...                 ...              ...
# 4999351                21                 170              719
# 4999352                21                 170              719
# 4999353                21                 170              719
# 4999354                21                 170              719
# 4999355                21                 170              719
#
#          ProductName_ID  ProductPackSKU_ID  Point-of-Sale_ID        Date  \
# 0                   657               1984                 2  2018-06-21
# ...

# %%
aux.shape
# Out:
# (9998511, 9)
